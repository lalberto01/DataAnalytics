# %% [markdown]
# # Exercise 2.A Using built-in functions

# %% [markdown]
# ## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name):
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]
    print(f"Full name: {name}")
    print(f"First name: {first}")
    print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0]) # output for Grace Flores
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores

# %%
parse_and_display(test_list[1]) # output for JB Oinonen
# Out:
# Full name: JB Oinonen
# First name: JB
# Last name: Oinonen

# %%
parse_and_display(test_list[2]) # output for Ken Penn
# Out:
# Full name: Ken Penn
# First name: Ken
# Last name: Penn

# %%
test_list = ['Lesley Alberto']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Lesley Alberto
# First name: Lesley
# Last name: Alberto

# %%
test_list = ["Megan Thee Stallion"]

# %%
parse_and_display2(test_list[0])
# Out:
# Full name: Megan Thee Stallion
# First name: Megan
# Middle name: Thee
# Last name: Stallion

# %%
test_list = ["Lesley Alberto Arellanes"]

# %%
parse_and_display2(test_list[0])
# Out:
# Full name: Lesley Alberto Arellanes
# First name: Lesley
# Middle name: Alberto
# Last name: Arellanes
